# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import numpy as np
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns

# %%
imsize=128
seed=123
tf.config.experimental.enable_op_determinism()
tf.random.set_seed(seed)
tf.keras.utils.set_random_seed(seed)
tf.keras.initializers.GlorotNormal(seed)
model_folder='Model/Fe_vs_Fi'
batch_size=16
num_epochs=150

# %%
def delete_files_in_directory(directory_path):
   try:
     files = os.listdir(directory_path)
     for file in files:
       file_path = os.path.join(directory_path, file)
       if os.path.isfile(file_path):
         os.remove(file_path)
     print(f"All files in {directory_path} deleted successfully.")
   except OSError:
     print(f"Error occurred while deleting files in {directory_path}.")

# Usage
directory_path = model_folder
delete_files_in_directory(directory_path)
# Out:
# All files in Model/Fe_vs_Fi deleted successfully.

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding="same", input_shape=(imsize, imsize, 1)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(2,2))
model.add(tf.keras.layers.Dropout(0.1))

model.add(tf.keras.layers.Conv2D(16, (3,3), activation='relu', padding="same"))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(2,2))
model.add(tf.keras.layers.Dropout(0.1))

model.add(tf.keras.layers.Conv2D(8, (3,3), activation='relu', padding="same"))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(2,2))
model.add(tf.keras.layers.Dropout(0.1))

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(32, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(32, activation='relu'))

model.add(tf.keras.layers.Dropout(0.1))

model.add(tf.keras.layers.BatchNormalization())

model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# d:\projects\cnn-mp-dos\venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 8)      │         1,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 8)      │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16, 16, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        65,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,409 (314.10 KB)
#  Trainable params: 80,233 (313.41 KB)
#  Non-trainable params: 176 (704.00 B)

# %%
model_filename = model_folder+'/CNN_Binary_F_Fi_{epoch}.keras'

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath = model_filename,
    monitor='val_loss',
    verbose=0,
    save_best_only=False,
    save_weights_only=False,
    mode='min',
    save_freq='epoch',
    initial_value_threshold=None
)

# %%
model.compile(optimizer = "Adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
#Training Data****************************************
ori_fe_fi_training_data_path='Data_Preprocessing/data_split_original/training_data/Fe_Fi'
ori_fe_fi_validation_data_path='Data_Preprocessing/data_split_original/validation_data/Fe_Fi'
ori_fe_fi_testing_data_path='Data_Preprocessing/data_split_original/testing_data/Fe_Fi'
save_train_dir='Data_Preprocessing/on_the_fly/Fe_Fi/train'
save_val_dir='Data_Preprocessing/on_the_fly/Fe_Fi/valid'
save_test_dir='Data_Preprocessing/on_the_fly/Fe_Fi/test'
#*****************************************************

delete_files_in_directory(save_test_dir)
delete_files_in_directory(save_val_dir)
delete_files_in_directory(save_train_dir)

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    ori_fe_fi_training_data_path,
    target_size=(imsize, imsize),
    batch_size=batch_size,
    class_mode='binary',
    color_mode='grayscale',
    shuffle=True,
    # save_to_dir=save_train_dir
)

val_generator = val_datagen.flow_from_directory(
    ori_fe_fi_validation_data_path,
    target_size=(imsize, imsize),
    batch_size=batch_size,
    class_mode='binary',
    color_mode='grayscale',
    shuffle=False,
    # save_to_dir=save_val_dir
)

test_generator = test_datagen.flow_from_directory(
    ori_fe_fi_testing_data_path,
    target_size=(imsize, imsize),
    batch_size=batch_size,
    save_to_dir=save_test_dir,
    class_mode='binary',
    color_mode='grayscale',
    shuffle=False
)
# Out:
# All files in Data_Preprocessing/on_the_fly/Fe_Fi/test deleted successfully.
# All files in Data_Preprocessing/on_the_fly/Fe_Fi/valid deleted successfully.
# All files in Data_Preprocessing/on_the_fly/Fe_Fi/train deleted successfully.
# Found 94 images belonging to 2 classes.
# Found 44 images belonging to 2 classes.
# Found 45 images belonging to 2 classes.

# %%
history = model.fit(train_generator, 
                    epochs=num_epochs, 
                    validation_data=val_generator, 
                    batch_size=batch_size, 
                    callbacks=[model_checkpoint])
# Out:
# d:\projects\cnn-mp-dos\venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.4584 - loss: 0.8920 - val_accuracy: 0.4545 - val_loss: 0.6949
# Epoch 2/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.6523 - loss: 0.5757 - val_accuracy: 0.4545 - val_loss: 0.7044
# Epoch 3/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.6868 - loss: 0.5529 - val_accuracy: 0.4545 - val_loss: 0.7132
# Epoch 4/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.7266 - loss: 0.5147 - val_accuracy: 0.4545 - val_loss: 0.7247
# Epoch 5/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.7971 - loss: 0.4565 - val_accuracy: 0.4545 - val_loss: 0.7413
# Epoch 6/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7730 - loss: 0.4164 - val_accuracy: 0.4545 - val_loss: 0.7572
# Epoch 7/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.8923 - loss: 0.3510 - val_accuracy: 0.4545 - val_loss: 0.7759
# Epoch 8/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.8736 - loss: 0.3370 - val_accuracy: 0.4545 - val_loss: 0.8042
# Epoch 9/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.9266 - loss: 0.2302 - val_accuracy: 0.4545 - val_loss: 0.8411
# Epoch 10/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9900 - loss: 0.1574 - val_accuracy: 0.4545 - val_loss: 0.8661
# Epoch 11/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.9898 - loss: 0.1531 - val_accuracy: 0.4545 - val_loss: 0.8911
# Epoch 12/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.9720 - loss: 0.1480 - val_accuracy: 0.4545 - val_loss: 0.9080
# Epoch 13/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.9928 - loss: 0.1013 - val_accuracy: 0.4545 - val_loss: 0.9334
# Epoch 14/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 1.0000 - loss: 0.0966 - val_accuracy: 0.4545 - val_loss: 0.9713
# Epoch 15/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.9765 - loss: 0.1457 - val_accuracy: 0.4545 - val_loss: 0.9912
# Epoch 16/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9609 - loss: 0.1336 - val_accuracy: 0.4545 - val_loss: 1.0272
# Epoch 17/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.9651 - loss: 0.1080 - val_accuracy: 0.4545 - val_loss: 1.1243
# Epoch 18/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.9951 - loss: 0.0687 - val_accuracy: 0.4545 - val_loss: 1.1993
# Epoch 19/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9802 - loss: 0.0813 - val_accuracy: 0.4545 - val_loss: 1.2305
# Epoch 20/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 1.0000 - loss: 0.0728 - val_accuracy: 0.4545 - val_loss: 1.2465
# Epoch 21/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.9970 - loss: 0.0555 - val_accuracy: 0.4545 - val_loss: 1.2899
# Epoch 22/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9929 - loss: 0.0628 - val_accuracy: 0.4545 - val_loss: 1.3161
# Epoch 23/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 1.0000 - loss: 0.0369 - val_accuracy: 0.4545 - val_loss: 1.3051
# Epoch 24/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 1.0000 - loss: 0.0423 - val_accuracy: 0.4545 - val_loss: 1.2960
# Epoch 25/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 1.0000 - loss: 0.0495 - val_accuracy: 0.4545 - val_loss: 1.2958
# Epoch 26/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.9856 - loss: 0.0627 - val_accuracy: 0.4545 - val_loss: 1.3184
# Epoch 27/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 1.0000 - loss: 0.0310 - val_accuracy: 0.4545 - val_loss: 1.3343
# Epoch 28/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 1.0000 - loss: 0.0424 - val_accuracy: 0.4545 - val_loss: 1.3433
# Epoch 29/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 1.0000 - loss: 0.0239 - val_accuracy: 0.4545 - val_loss: 1.3297
# Epoch 30/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.0387 - val_accuracy: 0.4545 - val_loss: 1.3179
# Epoch 31/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 1.0000 - loss: 0.0297 - val_accuracy: 0.4545 - val_loss: 1.2974
# Epoch 32/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 1.0000 - loss: 0.0398 - val_accuracy: 0.4545 - val_loss: 1.3235
# Epoch 33/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.4545 - val_loss: 1.3454
# Epoch 34/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.0248 - val_accuracy: 0.4545 - val_loss: 1.3496
# Epoch 35/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.4545 - val_loss: 1.3213
# Epoch 36/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 0.4545 - val_loss: 1.2921
# Epoch 37/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 1.0000 - loss: 0.0317 - val_accuracy: 0.4545 - val_loss: 1.3192
# Epoch 38/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 1.0000 - loss: 0.0245 - val_accuracy: 0.4545 - val_loss: 1.3739
# Epoch 39/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.9970 - loss: 0.0184 - val_accuracy: 0.4545 - val_loss: 1.3532
# Epoch 40/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.4545 - val_loss: 1.3234
# Epoch 41/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 1.0000 - loss: 0.0571 - val_accuracy: 0.4545 - val_loss: 1.2611
# Epoch 42/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 1.0000 - loss: 0.0424 - val_accuracy: 0.4545 - val_loss: 1.1872
# Epoch 43/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 0.4545 - val_loss: 1.1561
# Epoch 44/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.4545 - val_loss: 1.1396
# Epoch 45/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 0.4545 - val_loss: 1.0984
# Epoch 46/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 1.0000 - loss: 0.0249 - val_accuracy: 0.4545 - val_loss: 1.0130
# Epoch 47/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.4545 - val_loss: 0.9576
# Epoch 48/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.4545 - val_loss: 0.9780
# Epoch 49/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.4545 - val_loss: 1.0340
# Epoch 50/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.4545 - val_loss: 1.1166
# Epoch 51/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.4545 - val_loss: 1.1584
# Epoch 52/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.4545 - val_loss: 1.1739
# Epoch 53/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.4545 - val_loss: 1.2069
# Epoch 54/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.4545 - val_loss: 1.1735
# Epoch 55/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.9763 - loss: 0.0755 - val_accuracy: 0.4545 - val_loss: 1.1226
# Epoch 56/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.4545 - val_loss: 1.1221
# Epoch 57/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.4545 - val_loss: 1.0854
# Epoch 58/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.4545 - val_loss: 1.0617
# Epoch 59/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.9856 - loss: 0.0423 - val_accuracy: 0.4545 - val_loss: 1.0357
# Epoch 60/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 1.0000 - loss: 0.0167 - val_accuracy: 0.4773 - val_loss: 0.9759
# Epoch 61/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.9951 - loss: 0.0317 - val_accuracy: 0.4773 - val_loss: 0.9938
# Epoch 62/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.9928 - loss: 0.0298 - val_accuracy: 0.4773 - val_loss: 0.9598
# Epoch 63/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 1.0000 - loss: 0.0567 - val_accuracy: 0.4773 - val_loss: 0.8561
# Epoch 64/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 1.0000 - loss: 0.0188 - val_accuracy: 0.4773 - val_loss: 0.8631
# Epoch 65/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 0.4773 - val_loss: 0.9117
# Epoch 66/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 0.9951 - loss: 0.0104 - val_accuracy: 0.4773 - val_loss: 1.0931
# Epoch 67/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.9855 - loss: 0.0285 - val_accuracy: 0.4773 - val_loss: 0.9451
# Epoch 68/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.5227 - val_loss: 0.8236
# Epoch 69/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - accuracy: 1.0000 - loss: 0.0185 - val_accuracy: 0.6136 - val_loss: 0.7482
# Epoch 70/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 1.0000 - loss: 0.0263 - val_accuracy: 0.5909 - val_loss: 0.7544
# Epoch 71/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 0.5455 - val_loss: 0.8070
# Epoch 72/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 1.0000 - loss: 0.0349 - val_accuracy: 0.5909 - val_loss: 0.8107
# Epoch 73/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.5682 - val_loss: 0.8778
# Epoch 74/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 0.0271 - val_accuracy: 0.5455 - val_loss: 0.9449
# Epoch 75/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.9855 - loss: 0.0190 - val_accuracy: 0.7273 - val_loss: 0.7250
# Epoch 76/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 0.5909 - val_loss: 0.8295
# Epoch 77/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.5909 - val_loss: 0.9613
# Epoch 78/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.4773 - val_loss: 1.0692
# Epoch 79/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.5000 - val_loss: 1.1322
# Epoch 80/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.9929 - loss: 0.0243 - val_accuracy: 0.5682 - val_loss: 0.9577
# Epoch 81/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.6364 - val_loss: 0.7847
# Epoch 82/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.9939 - loss: 0.0285 - val_accuracy: 0.6364 - val_loss: 0.7733
# Epoch 83/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.5682 - val_loss: 1.0666
# Epoch 84/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.9939 - loss: 0.0279 - val_accuracy: 0.6136 - val_loss: 1.0031
# Epoch 85/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.6591 - val_loss: 0.7378
# Epoch 86/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 0.0259 - val_accuracy: 0.6818 - val_loss: 0.8263
# Epoch 87/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.6364 - val_loss: 1.0267
# Epoch 88/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.6591 - val_loss: 1.0372
# Epoch 89/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.6591 - val_loss: 0.9716
# Epoch 90/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.7045 - val_loss: 0.9143
# Epoch 91/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.7045 - val_loss: 0.8898
# Epoch 92/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.7273 - val_loss: 0.8869
# Epoch 93/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 0.7045 - val_loss: 0.9762
# Epoch 94/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.6818 - val_loss: 1.0732
# Epoch 95/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.9970 - loss: 0.0232 - val_accuracy: 0.7045 - val_loss: 1.0226
# Epoch 96/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.7273 - val_loss: 0.9898
# Epoch 97/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.7273 - val_loss: 0.9342
# Epoch 98/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.7500 - val_loss: 0.8821
# Epoch 99/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.7500 - val_loss: 0.8636
# Epoch 100/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.7273 - val_loss: 0.9337
# Epoch 101/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.7045 - val_loss: 1.0352
# Epoch 102/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.7045 - val_loss: 1.0854
# Epoch 103/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.7273 - val_loss: 1.0068
# Epoch 104/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.7273 - val_loss: 0.9558
# Epoch 105/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.7273 - val_loss: 0.9170
# Epoch 106/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7500 - val_loss: 0.8785
# Epoch 107/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.7500 - val_loss: 0.7911
# Epoch 108/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8182 - val_loss: 0.7670
# Epoch 109/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8182 - val_loss: 0.7647
# Epoch 110/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8182 - val_loss: 0.7703
# Epoch 111/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 0.8409 - val_loss: 0.7131
# Epoch 112/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.7955 - val_loss: 0.7149
# Epoch 113/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.7727 - val_loss: 0.7469
# Epoch 114/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 0.9970 - loss: 0.0240 - val_accuracy: 0.7955 - val_loss: 0.7726
# Epoch 115/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.7045 - val_loss: 0.9715
# Epoch 116/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - accuracy: 0.9929 - loss: 0.0148 - val_accuracy: 0.8182 - val_loss: 0.7460
# Epoch 117/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8182 - val_loss: 0.6435
# Epoch 118/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 0.8182 - val_loss: 0.6874
# Epoch 119/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.7727 - val_loss: 0.7610
# Epoch 120/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.9855 - loss: 0.0315 - val_accuracy: 0.7500 - val_loss: 0.8255
# Epoch 121/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.7273 - val_loss: 0.8263
# Epoch 122/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7727 - val_loss: 0.8059
# Epoch 123/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.7727 - val_loss: 0.8006
# Epoch 124/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.7955 - val_loss: 0.7790
# Epoch 125/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 1.0000 - loss: 0.0352 - val_accuracy: 0.7955 - val_loss: 0.9468
# Epoch 126/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.7955 - val_loss: 1.0216
# Epoch 127/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.7955 - val_loss: 1.0151
# Epoch 128/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.9929 - loss: 0.0237 - val_accuracy: 0.8182 - val_loss: 1.0186
# Epoch 129/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.7500 - val_loss: 1.1687
# Epoch 130/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.7273 - val_loss: 1.2113
# Epoch 131/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.7500 - val_loss: 1.1702
# Epoch 132/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.7045 - val_loss: 1.2117
# Epoch 133/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.7045 - val_loss: 1.2631
# Epoch 134/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.7045 - val_loss: 1.2810
# Epoch 135/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7045 - val_loss: 1.2937
# Epoch 136/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7273 - val_loss: 1.3123
# Epoch 137/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - accuracy: 0.9951 - loss: 0.0123 - val_accuracy: 0.7273 - val_loss: 1.4115
# Epoch 138/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.7045 - val_loss: 1.5802
# Epoch 139/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - accuracy: 0.9610 - loss: 0.0466 - val_accuracy: 0.7500 - val_loss: 1.0458
# Epoch 140/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.9951 - loss: 0.0074 - val_accuracy: 0.7727 - val_loss: 1.0036
# Epoch 141/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.7955 - val_loss: 1.0076
# Epoch 142/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.9855 - loss: 0.0137 - val_accuracy: 0.7727 - val_loss: 0.9309
# Epoch 143/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 0.7727 - val_loss: 0.8899
# Epoch 144/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 0.7955 - val_loss: 0.8709
# Epoch 145/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.7955 - val_loss: 0.9421
# Epoch 146/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7273 - val_loss: 1.3002
# Epoch 147/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.7045 - val_loss: 1.4354
# Epoch 148/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 0.7273 - val_loss: 1.3581
# Epoch 149/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.7727 - val_loss: 1.0248
# Epoch 150/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.9952 - loss: 0.0207 - val_accuracy: 0.8636 - val_loss: 0.9528

# %%
plt.subplots(figsize=(4, 3))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy', color='red', fontsize = 15)
plt.xlabel('Epoch', color='red', fontsize = 15)
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

# %%
plt.subplots(figsize=(4, 3));
plt.plot(history.history['loss']);
plt.plot(history.history['val_loss']);
plt.ylabel('Loss', color='red', fontsize = 15);
plt.xlabel('Epoch', color='red', fontsize = 15);
plt.legend(['Training Loss', 'Validation Loss']);
plt.grid()

# %% [markdown]
# **EVALUATING ALL  MODELS**: *Selecting BEST MODEL (BEST ACCURACY)*

# %%
test_generator.class_indices
# Out:
# {'class_fe': 0, 'class_fi': 1}

# %%
import re
#Selecting BEST MODEL (BEST ACCURACY)
LABELS=['Ferromagnetic','Ferrimagnetic']
dir_list = os.listdir(model_folder)
best_epoch=-1
best_model=''
acc_max=-1
actual_class = test_generator.labels
for filename in dir_list:
    model_check = tf.keras.models.load_model(model_folder+'/'+filename)
    predicted_class =((model_check.predict(test_generator) > .5).astype(int))
    report=classification_report(actual_class, predicted_class, target_names=LABELS,output_dict=True,zero_division=np.nan)
    if report['accuracy']>acc_max:
        best_model=model_folder+'/'+filename
        r=re.findall('[0-9]+', filename)
        best_epoch=int(r[0])        
        acc_max=report['accuracy']

model_eval = tf.keras.models.load_model(best_model)
predicted_class =((model_eval.predict(test_generator) > .5).astype(int))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step

# %%
cf_mtx = confusion_matrix(test_generator.labels, predicted_class)
group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2,2)

plt.figure(figsize = (4,3))
sns.heatmap(cf_mtx, xticklabels=LABELS, yticklabels=LABELS,
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
report=classification_report(test_generator.labels, predicted_class, target_names=['Ferromagnetic', 'Ferrimagnetic'])
print(f'Best Model: {best_model}')
print('=======================================================')
print(report)
# Out:
# Best Model: Model/Fe_vs_Fi/CNN_Binary_F_Fi_122.keras
# =======================================================
#                precision    recall  f1-score   support
#
# Ferromagnetic       0.78      0.75      0.77        24
# Ferrimagnetic       0.73      0.76      0.74        21
#
#      accuracy                           0.76        45
#     macro avg       0.75      0.76      0.76        45
#  weighted avg       0.76      0.76      0.76        45

# %%
import pandas as pd

train_loss,train_acc=model_eval.evaluate(train_generator,verbose=0)
val_loss,val_acc=model_eval.evaluate(val_generator,verbose=0)
test_loss,test_acc=model_eval.evaluate(test_generator,verbose=0)
dict_df={'Accuracy':[train_acc,val_acc,test_acc],'Loss':[train_loss,val_loss,test_loss]}

print(f'Best Model: {best_model}')
df=pd.DataFrame(dict_df,index=['Training','Validation','Testing'])
df
# Out:
# Best Model: Model/Fe_vs_Fi/CNN_Binary_F_Fi_122.keras
#             Accuracy      Loss
# Training    1.000000  0.018964
# Validation  0.772727  0.805939
# Testing     0.755556  0.877430
