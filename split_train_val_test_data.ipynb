# %%
import os

# %% [markdown]
# *Directory Management*

# %%
#**********Original Data location *****************
ori_data_path='Data_Preprocessing/data_all_original'

#Fe_Fi
DirFeFi_classFe = ori_data_path+'/Fe_Fi/Ferromagnetic'
DirFeFi_classFi = ori_data_path+'/Fe_Fi/Ferrimagnetic'

#Fe_NM
DirFeNM_classFe = ori_data_path+'/Fe_NM/Ferromagnetic'
DirFeNM_classNM = ori_data_path+'/Fe_NM/Non_Magnetic'

#Fe_Fi_NM
DirFeFiNM_classFe = ori_data_path+'/Fe_Fi_NM/Ferromagnetic'
DirFeFiNM_classFi = ori_data_path+'/Fe_Fi_NM/Ferrimagnetic'
DirFeFiNM_classNM = ori_data_path+'/Fe_Fi_NM/Non_Magnetic'

#*******************************************************

#*************Data Split Location**********************
#Split Destination Copy
main_split_path='Data_Preprocessing/data_split_original'

#Training Dir
main_training_data_path=main_split_path+'/training_data'

#Fe_Fi
fe_fi_training_fe_data_path=main_training_data_path+'/Fe_Fi/class_fe/Ferromagnetic'
fe_fi_training_fi_data_path=main_training_data_path+'/Fe_Fi/class_fi/Ferrimagnetic'

#Fe_Fi_NM
fe_nm_training_fe_data_path=main_training_data_path+'/Fe_NM/class_fe/Ferromagnetic'
fe_nm_training_nm_data_path=main_training_data_path+'/Fe_NM/class_nm/Non_Magnetic'

#Fe_Fi_NM
fe_fi_nm_training_fe_data_path=main_training_data_path+'/Fe_Fi_NM/class_fe/Ferromagnetic'
fe_fi_nm_training_fi_data_path=main_training_data_path+'/Fe_Fi_NM/class_fi/Ferrimagnetic'
fe_fi_nm_training_nm_data_path=main_training_data_path+'/Fe_Fi_NM/class_nm/Non_Magnetic'

#Training Dir
main_validation_data_path=main_split_path+'/validation_data'

#Fe_Fi
fe_fi_validation_fe_data_path=main_validation_data_path+'/Fe_Fi/class_fe/Ferromagnetic'
fe_fi_validation_fi_data_path=main_validation_data_path+'/Fe_Fi/class_fi/Ferrimagnetic'

#Fe_Fi_NM
fe_nm_validation_fe_data_path=main_validation_data_path+'/Fe_NM/class_fe/Ferromagnetic'
fe_nm_validation_nm_data_path=main_validation_data_path+'/Fe_NM/class_nm/Non_Magnetic'

#Fe_Fi_NM
fe_fi_nm_validation_fe_data_path=main_validation_data_path+'/Fe_Fi_NM/class_fe/Ferromagnetic'
fe_fi_nm_validation_fi_data_path=main_validation_data_path+'/Fe_Fi_NM/class_fi/Ferrimagnetic'
fe_fi_nm_validation_nm_data_path=main_validation_data_path+'/Fe_Fi_NM/class_nm/Non_Magnetic'

#Testing Dir
main_testing_data_path=main_split_path+'/testing_data'

#Fe_Fi
fe_fi_testing_fe_data_path=main_testing_data_path+'/Fe_Fi/class_fe/Ferromagnetic'
fe_fi_testing_fi_data_path=main_testing_data_path+'/Fe_Fi/class_fi/Ferrimagnetic'

#Fe_NM
fe_nm_testing_fe_data_path=main_testing_data_path+'/Fe_NM/class_fe/Ferromagnetic'
fe_nm_testing_nm_data_path=main_testing_data_path+'/Fe_NM/class_nm/Non_Magnetic'

#Fe_Fi_NM
fe_fi_nm_testing_fe_data_path=main_testing_data_path+'/Fe_Fi_NM/class_fe/Ferromagnetic'
fe_fi_nm_testing_fi_data_path=main_testing_data_path+'/Fe_Fi_NM/class_fi/Ferrimagnetic'
fe_fi_nm_testing_nm_data_path=main_testing_data_path+'/Fe_Fi_NM/class_nm/Non_Magnetic'

# %%
def delete_files_in_directory(directory_path):
   try:
     files = os.listdir(directory_path)
     for file in files:
       file_path = os.path.join(directory_path, file)
       if os.path.isfile(file_path):
         os.remove(file_path)
     print(f"All files in {directory_path} deleted successfully.")
   except OSError:
     print(f"Error occurred while deleting files in {directory_path}.")

# %% [markdown]
# Creating Training-Validation-Testing data

# %% [markdown]
# *Fe_Fi: Ferromagnetic*

# %%
import random
import shutil 
random.seed(10)

source=DirFeFi_classFe

test_size=0.20
valid_size=0.20
dir_list = os.listdir(source) 
ntest=int(test_size*len(dir_list))
nvalid=int(valid_size*len(dir_list))
ntrain=len(dir_list)-ntest-nvalid

rtest=[]
for i in range(0,ntest):
    r = random.randint(0, len(dir_list)-1)
    rtest.append(r)

rvalid=[]
# for i in range(0,len(dir_list)):
r = random.randint(0, len(dir_list)-1)
while len(rvalid)!=nvalid:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest:
        rvalid.append(r)

rtrain=[]
r = random.randint(0, len(dir_list)-1)
while len(rtrain) != ntrain:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest and r not in rvalid:
        rtrain.append(r)

print(rtest)
print(rvalid)
print(rtrain)

# Usage
delete_files_in_directory(fe_fi_testing_fe_data_path)
delete_files_in_directory(fe_fi_training_fe_data_path)
delete_files_in_directory(fe_fi_validation_fe_data_path)

testing_destination_path=fe_fi_testing_fe_data_path
training_destination_path=fe_fi_training_fe_data_path
validation_destination_path=fe_fi_validation_fe_data_path


#Creating testing data 
for i in rtest:
    shutil.copyfile(source+'/'+dir_list[i], testing_destination_path+'/'+dir_list[i]) 

#Creating training data 
for i in rtrain:
    shutil.copyfile(source+'/'+dir_list[i], training_destination_path+'/'+dir_list[i]) 

#Creating validation data 
for i in rvalid:
    shutil.copyfile(source+'/'+dir_list[i], validation_destination_path+'/'+dir_list[i]) 

print('... replaced by new files')
# Out:
# [8, 109, 123, 3, 52, 118, 125, 71, 41, 8, 133, 125, 83, 19, 63, 92, 11, 107, 35, 90, 97, 107, 72, 67, 116, 44, 77]
# [34, 61, 112, 96, 1, 60, 34, 49, 93, 61, 80, 115, 111, 120, 16, 128, 40, 57, 105, 61, 9, 127, 18, 20, 38, 98, 95]
# [28, 24, 113, 42, 48, 89, 110, 106, 114, 62, 70, 36, 45, 30, 68, 42, 45, 122, 88, 84, 81, 62, 114, 103, 99, 126, 134, 69, 42, 102, 89, 99, 42, 25, 106, 0, 12, 89, 23, 27, 124, 117, 114, 87, 66, 117, 108, 84, 39, 82, 50, 122, 6, 29, 75, 74, 22, 27, 73, 122, 36, 102, 89, 46, 53, 24, 78, 108, 114, 53, 68, 29, 53, 108, 104, 51, 17, 108, 22, 14, 89]
# All files in Data_Preprocessing/data_split_original/testing_data/Fe_Fi/class_fe/Ferromagnetic deleted successfully.
# All files in Data_Preprocessing/data_split_original/training_data/Fe_Fi/class_fe/Ferromagnetic deleted successfully.
# All files in Data_Preprocessing/data_split_original/validation_data/Fe_Fi/class_fe/Ferromagnetic deleted successfully.
# ... replaced by new files

# %% [markdown]
# *Fe_Fi: Ferrimagnetic*

# %%
random.seed(10)

source=DirFeFi_classFi

test_size=0.20
valid_size=0.20
dir_list = os.listdir(source) 
ntest=int(test_size*len(dir_list))
nvalid=int(valid_size*len(dir_list))
ntrain=len(dir_list)-ntest-nvalid

rtest=[]
for i in range(0,ntest):
    r = random.randint(0, len(dir_list)-1)
    rtest.append(r)

rvalid=[]
# for i in range(0,len(dir_list)):
r = random.randint(0, len(dir_list)-1)
while len(rvalid)!=nvalid:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest:
        rvalid.append(r)

rtrain=[]
r = random.randint(0, len(dir_list)-1)
while len(rtrain) != ntrain:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest and r not in rvalid:
        rtrain.append(r)

print(rtest)
print(rvalid)
print(rtrain)

# Usage
delete_files_in_directory(fe_fi_testing_fi_data_path)
delete_files_in_directory(fe_fi_training_fi_data_path)
delete_files_in_directory(fe_fi_validation_fi_data_path)

testing_destination_path=fe_fi_testing_fi_data_path
training_destination_path=fe_fi_training_fi_data_path
validation_destination_path=fe_fi_validation_fi_data_path


#Creating testing data 
for i in rtest:
    shutil.copyfile(source+'/'+dir_list[i], testing_destination_path+'/'+dir_list[i]) 

#Creating training data 
for i in rtrain:
    shutil.copyfile(source+'/'+dir_list[i], training_destination_path+'/'+dir_list[i]) 

#Creating validation data 
for i in rvalid:
    shutil.copyfile(source+'/'+dir_list[i], validation_destination_path+'/'+dir_list[i]) 

print('... replaced by new files')
# Out:
# [73, 4, 54, 61, 73, 1, 26, 59, 104, 62, 105, 35, 83, 103, 20, 4, 66, 62, 41, 9, 31, 95, 46, 5]
# [110, 17, 77, 45, 48, 53, 36, 86, 33, 58, 22, 87, 38, 84, 17, 58, 98, 110, 30, 56, 78, 48, 74, 0]
# [24, 116, 68, 114, 40, 85, 70, 57, 55, 60, 8, 108, 64, 107, 28, 52, 63, 68, 118, 109, 10, 19, 49, 72, 47, 116, 76, 19, 14, 99, 12, 21, 24, 44, 55, 57, 18, 79, 15, 34, 21, 99, 44, 55, 28, 69, 91, 42, 114, 40, 10, 57, 51, 49, 117, 111, 63, 114, 94, 67, 116, 34, 63, 8, 21, 114, 51, 69, 44, 68, 49, 89]
# All files in Data_Preprocessing/data_split_original/testing_data/Fe_Fi/class_fi/Ferrimagnetic deleted successfully.
# All files in Data_Preprocessing/data_split_original/training_data/Fe_Fi/class_fi/Ferrimagnetic deleted successfully.
# All files in Data_Preprocessing/data_split_original/validation_data/Fe_Fi/class_fi/Ferrimagnetic deleted successfully.
# ... replaced by new files

# %% [markdown]
# *Fe_NM: Ferromagnetic*

# %%
random.seed(10)

source=DirFeNM_classFe

test_size=0.20
valid_size=0.20
dir_list = os.listdir(source) 
ntest=int(test_size*len(dir_list))
nvalid=int(valid_size*len(dir_list))
ntrain=len(dir_list)-ntest-nvalid

rtest=[]
for i in range(0,ntest):
    r = random.randint(0, len(dir_list)-1)
    rtest.append(r)

rvalid=[]
# for i in range(0,len(dir_list)):
r = random.randint(0, len(dir_list)-1)
while len(rvalid)!=nvalid:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest:
        rvalid.append(r)

rtrain=[]
r = random.randint(0, len(dir_list)-1)
while len(rtrain) != ntrain:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest and r not in rvalid:
        rtrain.append(r)

print(rtest)
print(rvalid)
print(rtrain)

# Usage
delete_files_in_directory(fe_nm_testing_fe_data_path)
delete_files_in_directory(fe_nm_training_fe_data_path)
delete_files_in_directory(fe_nm_validation_fe_data_path)

testing_destination_path=fe_nm_testing_fe_data_path
training_destination_path=fe_nm_training_fe_data_path
validation_destination_path=fe_nm_validation_fe_data_path


#Creating testing data 
for i in rtest:
    shutil.copyfile(source+'/'+dir_list[i], testing_destination_path+'/'+dir_list[i]) 

#Creating training data 
for i in rtrain:
    shutil.copyfile(source+'/'+dir_list[i], training_destination_path+'/'+dir_list[i]) 

#Creating validation data 
for i in rvalid:
    shutil.copyfile(source+'/'+dir_list[i], validation_destination_path+'/'+dir_list[i]) 

print('... replaced by new files')
# Out:
# [8, 109, 123, 3, 52, 118, 125, 71, 41, 8, 133, 125, 83, 19, 63, 92, 11, 107, 35, 90, 97, 107, 72, 67, 116, 44, 77]
# [34, 61, 112, 96, 1, 60, 34, 49, 137, 93, 61, 80, 115, 111, 120, 16, 128, 40, 57, 105, 61, 9, 127, 18, 136, 20, 38]
# [95, 28, 24, 113, 42, 48, 89, 110, 106, 114, 62, 70, 36, 45, 30, 68, 42, 45, 122, 88, 84, 81, 62, 114, 103, 99, 126, 134, 69, 42, 102, 89, 99, 42, 25, 106, 0, 12, 89, 23, 27, 124, 117, 114, 87, 66, 117, 108, 84, 39, 82, 50, 122, 6, 29, 75, 74, 22, 27, 73, 122, 36, 102, 89, 46, 53, 24, 78, 108, 114, 53, 68, 29, 53, 108, 104, 51, 17, 108, 22, 14, 89, 65, 108]
# All files in Data_Preprocessing/data_split_original/testing_data/Fe_NM/class_fe/Ferromagnetic deleted successfully.
# All files in Data_Preprocessing/data_split_original/training_data/Fe_NM/class_fe/Ferromagnetic deleted successfully.
# All files in Data_Preprocessing/data_split_original/validation_data/Fe_NM/class_fe/Ferromagnetic deleted successfully.
# ... replaced by new files

# %% [markdown]
# *Fe_NM: Non_Magnetic*

# %%
random.seed(10)

source=DirFeNM_classNM

test_size=0.20
valid_size=0.20
dir_list = os.listdir(source) 
ntest=int(test_size*len(dir_list))
nvalid=int(valid_size*len(dir_list))
ntrain=len(dir_list)-ntest-nvalid

rtest=[]
for i in range(0,ntest):
    r = random.randint(0, len(dir_list)-1)
    rtest.append(r)

rvalid=[]
# for i in range(0,len(dir_list)):
r = random.randint(0, len(dir_list)-1)
while len(rvalid)!=nvalid:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest:
        rvalid.append(r)

rtrain=[]
r = random.randint(0, len(dir_list)-1)
while len(rtrain) != ntrain:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest and r not in rvalid:
        rtrain.append(r)

print(rtest)
print(rvalid)
print(rtrain)

# Usage
delete_files_in_directory(fe_nm_testing_nm_data_path)
delete_files_in_directory(fe_nm_training_nm_data_path)
delete_files_in_directory(fe_nm_validation_nm_data_path)

testing_destination_path=fe_nm_testing_nm_data_path
training_destination_path=fe_nm_training_nm_data_path
validation_destination_path=fe_nm_validation_nm_data_path

#Creating testing data 
for i in rtest:
    shutil.copyfile(source+'/'+dir_list[i], testing_destination_path+'/'+dir_list[i]) 

#Creating training data 
for i in rtrain:
    shutil.copyfile(source+'/'+dir_list[i], training_destination_path+'/'+dir_list[i]) 

#Creating validation data 
for i in rvalid:
    shutil.copyfile(source+'/'+dir_list[i], validation_destination_path+'/'+dir_list[i]) 

print('... replaced by new files')
# Out:
# [146, 8, 109, 123, 147, 3, 52, 118, 125, 71, 41, 8, 133, 125, 83, 19, 63, 92, 11, 107, 35, 90, 97, 107, 72, 67, 116, 44, 77, 92]
# [61, 112, 96, 149, 1, 60, 34, 49, 137, 93, 61, 80, 140, 115, 111, 120, 16, 149, 128, 40, 57, 105, 61, 9, 127, 18, 136, 20, 38, 98]
# [95, 28, 24, 113, 42, 48, 89, 110, 106, 114, 62, 70, 36, 45, 30, 68, 42, 45, 122, 88, 139, 84, 81, 62, 114, 103, 99, 126, 134, 69, 42, 102, 138, 89, 99, 42, 143, 25, 106, 0, 12, 89, 23, 27, 124, 117, 114, 87, 66, 117, 108, 84, 39, 82, 50, 122, 6, 29, 75, 74, 22, 27, 73, 122, 36, 102, 89, 46, 53, 24, 78, 108, 114, 142, 53, 68, 29, 53, 108, 104, 51, 17, 108, 22, 14, 89, 65, 108, 119, 75]
# All files in Data_Preprocessing/data_split_original/testing_data/Fe_NM/class_nm/Non_Magnetic deleted successfully.
# All files in Data_Preprocessing/data_split_original/training_data/Fe_NM/class_nm/Non_Magnetic deleted successfully.
# ...

# %% [markdown]
# *Fe_Fi_NM: Ferromagnetic*

# %%
random.seed(10)

source=DirFeFiNM_classFe

test_size=0.20
valid_size=0.20
dir_list = os.listdir(source) 
ntest=int(test_size*len(dir_list))
nvalid=int(valid_size*len(dir_list))
ntrain=len(dir_list)-ntest-nvalid

rtest=[]
for i in range(0,ntest):
    r = random.randint(0, len(dir_list)-1)
    rtest.append(r)

rvalid=[]
# for i in range(0,len(dir_list)):
r = random.randint(0, len(dir_list)-1)
while len(rvalid)!=nvalid:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest:
        rvalid.append(r)

rtrain=[]
r = random.randint(0, len(dir_list)-1)
while len(rtrain) != ntrain:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest and r not in rvalid:
        rtrain.append(r)

print(rtest)
print(rvalid)
print(rtrain)

# Usage
delete_files_in_directory(fe_fi_nm_testing_fe_data_path)
delete_files_in_directory(fe_fi_nm_training_fe_data_path)
delete_files_in_directory(fe_fi_nm_validation_fe_data_path)

testing_destination_path=fe_fi_nm_testing_fe_data_path
training_destination_path=fe_fi_nm_training_fe_data_path
validation_destination_path=fe_fi_nm_validation_fe_data_path

#Creating testing data 
for i in rtest:
    shutil.copyfile(source+'/'+dir_list[i], testing_destination_path+'/'+dir_list[i]) 

#Creating training data 
for i in rtrain:
    shutil.copyfile(source+'/'+dir_list[i], training_destination_path+'/'+dir_list[i]) 

#Creating validation data 
for i in rvalid:
    shutil.copyfile(source+'/'+dir_list[i], validation_destination_path+'/'+dir_list[i]) 

print('... replaced by new files')
# Out:
# [8, 109, 123, 3, 52, 118, 125, 71, 41, 8, 133, 125, 83, 19, 63, 92, 11, 107, 35, 90, 97, 107, 72, 67, 116, 44, 77]
# [34, 61, 112, 96, 1, 60, 34, 49, 93, 61, 80, 115, 111, 120, 16, 128, 40, 57, 105, 61, 9, 127, 18, 20, 38, 98, 95]
# [28, 24, 113, 42, 48, 89, 110, 106, 114, 62, 70, 36, 45, 30, 68, 42, 45, 122, 88, 84, 81, 62, 114, 103, 99, 126, 134, 69, 42, 102, 89, 99, 42, 25, 106, 0, 12, 89, 23, 27, 124, 117, 114, 87, 66, 117, 108, 84, 39, 82, 50, 122, 6, 29, 75, 74, 22, 27, 73, 122, 36, 102, 89, 46, 53, 24, 78, 108, 114, 53, 68, 29, 53, 108, 104, 51, 17, 108, 22, 14, 89]
# All files in Data_Preprocessing/data_split_original/testing_data/Fe_Fi_NM/class_fe/Ferromagnetic deleted successfully.
# All files in Data_Preprocessing/data_split_original/training_data/Fe_Fi_NM/class_fe/Ferromagnetic deleted successfully.
# All files in Data_Preprocessing/data_split_original/validation_data/Fe_Fi_NM/class_fe/Ferromagnetic deleted successfully.
# ... replaced by new files

# %% [markdown]
# *Fe_Fi_NM: Ferrimagnetic*

# %%
random.seed(10)

source=DirFeFiNM_classFi

test_size=0.20
valid_size=0.20
dir_list = os.listdir(source) 
ntest=int(test_size*len(dir_list))
nvalid=int(valid_size*len(dir_list))
ntrain=len(dir_list)-ntest-nvalid

rtest=[]
for i in range(0,ntest):
    r = random.randint(0, len(dir_list)-1)
    rtest.append(r)

rvalid=[]
# for i in range(0,len(dir_list)):
r = random.randint(0, len(dir_list)-1)
while len(rvalid)!=nvalid:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest:
        rvalid.append(r)

rtrain=[]
r = random.randint(0, len(dir_list)-1)
while len(rtrain) != ntrain:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest and r not in rvalid:
        rtrain.append(r)

print(rtest)
print(rvalid)
print(rtrain)

# Usage
delete_files_in_directory(fe_fi_nm_testing_fi_data_path)
delete_files_in_directory(fe_fi_nm_training_fi_data_path)
delete_files_in_directory(fe_fi_nm_validation_fi_data_path)

testing_destination_path=fe_fi_nm_testing_fi_data_path
training_destination_path=fe_fi_nm_training_fi_data_path
validation_destination_path=fe_fi_nm_validation_fi_data_path

#Creating testing data 
for i in rtest:
    shutil.copyfile(source+'/'+dir_list[i], testing_destination_path+'/'+dir_list[i]) 

#Creating training data 
for i in rtrain:
    shutil.copyfile(source+'/'+dir_list[i], training_destination_path+'/'+dir_list[i]) 

#Creating validation data 
for i in rvalid:
    shutil.copyfile(source+'/'+dir_list[i], validation_destination_path+'/'+dir_list[i]) 

print('... replaced by new files')
# Out:
# [73, 4, 54, 61, 73, 1, 26, 59, 104, 62, 105, 35, 83, 103, 20, 4, 66, 62, 41, 9, 31, 95, 46, 5]
# [110, 17, 77, 45, 48, 53, 36, 86, 33, 58, 22, 87, 38, 84, 17, 58, 98, 110, 30, 56, 78, 48, 74, 0]
# [24, 116, 68, 114, 40, 85, 70, 57, 55, 60, 8, 108, 64, 107, 28, 52, 63, 68, 118, 109, 10, 19, 49, 72, 47, 116, 76, 19, 14, 99, 12, 21, 24, 44, 55, 57, 18, 79, 15, 34, 21, 99, 44, 55, 28, 69, 91, 42, 114, 40, 10, 57, 51, 49, 117, 111, 63, 114, 94, 67, 116, 34, 63, 8, 21, 114, 51, 69, 44, 68, 49, 89]
# All files in Data_Preprocessing/data_split_original/testing_data/Fe_Fi_NM/class_fi/Ferrimagnetic deleted successfully.
# All files in Data_Preprocessing/data_split_original/training_data/Fe_Fi_NM/class_fi/Ferrimagnetic deleted successfully.
# All files in Data_Preprocessing/data_split_original/validation_data/Fe_Fi_NM/class_fi/Ferrimagnetic deleted successfully.
# ... replaced by new files

# %% [markdown]
# *Fe_Fi_NM: Non_Magnetic*

# %%
random.seed(10)

source=DirFeFiNM_classNM

test_size=0.20
valid_size=0.20
dir_list = os.listdir(source) 
ntest=int(test_size*len(dir_list))
nvalid=int(valid_size*len(dir_list))
ntrain=len(dir_list)-ntest-nvalid

rtest=[]
for i in range(0,ntest):
    r = random.randint(0, len(dir_list)-1)
    rtest.append(r)

rvalid=[]
# for i in range(0,len(dir_list)):
r = random.randint(0, len(dir_list)-1)
while len(rvalid)!=nvalid:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest:
        rvalid.append(r)

rtrain=[]
r = random.randint(0, len(dir_list)-1)
while len(rtrain) != ntrain:
    r = random.randint(0, len(dir_list)-1)
    if r not in rtest and r not in rvalid:
        rtrain.append(r)

print(rtest)
print(rvalid)
print(rtrain)

# Usage
delete_files_in_directory(fe_fi_nm_testing_nm_data_path)
delete_files_in_directory(fe_fi_nm_training_nm_data_path)
delete_files_in_directory(fe_fi_nm_validation_nm_data_path)

testing_destination_path=fe_fi_nm_testing_nm_data_path
training_destination_path=fe_fi_nm_training_nm_data_path
validation_destination_path=fe_fi_nm_validation_nm_data_path

#Creating testing data 
for i in rtest:
    shutil.copyfile(source+'/'+dir_list[i], testing_destination_path+'/'+dir_list[i]) 

#Creating training data 
for i in rtrain:
    shutil.copyfile(source+'/'+dir_list[i], training_destination_path+'/'+dir_list[i]) 

#Creating validation data 
for i in rvalid:
    shutil.copyfile(source+'/'+dir_list[i], validation_destination_path+'/'+dir_list[i]) 

print('... replaced by new files')
# Out:
# [146, 8, 109, 123, 147, 3, 52, 118, 125, 71, 41, 8, 133, 125, 83, 19, 63, 92, 11, 107, 35, 90, 97, 107, 72, 67, 116, 44, 77, 92]
# [61, 112, 96, 149, 1, 60, 34, 49, 137, 93, 61, 80, 140, 115, 111, 120, 16, 149, 128, 40, 57, 105, 61, 9, 127, 18, 136, 20, 38, 98]
# [95, 28, 24, 113, 42, 48, 89, 110, 106, 114, 62, 70, 36, 45, 30, 68, 42, 45, 122, 88, 139, 84, 81, 62, 114, 103, 99, 126, 134, 69, 42, 102, 138, 89, 99, 42, 143, 25, 106, 0, 12, 89, 23, 27, 124, 117, 114, 87, 66, 117, 108, 84, 39, 82, 50, 122, 6, 29, 75, 74, 22, 27, 73, 122, 36, 102, 89, 46, 53, 24, 78, 108, 114, 142, 53, 68, 29, 53, 108, 104, 51, 17, 108, 22, 14, 89, 65, 108, 119, 75]
# All files in Data_Preprocessing/data_split_original/testing_data/Fe_Fi_NM/class_nm/Non_Magnetic deleted successfully.
# All files in Data_Preprocessing/data_split_original/training_data/Fe_Fi_NM/class_nm/Non_Magnetic deleted successfully.
# ...
