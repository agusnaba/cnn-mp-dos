# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import numpy as np
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns

# %%
seed=123
tf.config.experimental.enable_op_determinism()
tf.random.set_seed(seed)
tf.keras.utils.set_random_seed(seed)
tf.keras.initializers.GlorotNormal(seed)

model_folder='Model/Fe_Fi_NM'
imsize=128
batch_size=16
num_epochs=150

# %%
def delete_files_in_directory(directory_path):
   try:
     files = os.listdir(directory_path)
     for file in files:
       file_path = os.path.join(directory_path, file)
       if os.path.isfile(file_path):
         os.remove(file_path)
     print(f"All files in {directory_path} deleted successfully.")
   except OSError:
     print(f"Error occurred while deleting files in {directory_path}.")

# Usage
delete_files_in_directory(model_folder)
# Out:
# All files in Model/Fe_Fi_NM deleted successfully.

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding="same", input_shape=(imsize, imsize, 1)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(2,2))
model.add(tf.keras.layers.Dropout(0.1))

model.add(tf.keras.layers.Conv2D(16, (3,3), activation='relu', padding="same"))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(2,2))
model.add(tf.keras.layers.Dropout(0.1))

model.add(tf.keras.layers.Conv2D(8, (3,3), activation='relu', padding="same"))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D(2,2))
model.add(tf.keras.layers.Dropout(0.1))

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(32, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(32, activation='relu'))

model.add(tf.keras.layers.Dropout(0.1))

model.add(tf.keras.layers.BatchNormalization())

# model.add(tf.keras.layers.Dense(3, activation='sigmoid'))
model.add(tf.keras.layers.Dense(3, activation='softmax'))

model.summary()
# Out:
# d:\projects\cnn-mp-dos\venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 8)      │         1,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 8)      │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16, 16, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        65,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80,475 (314.36 KB)
#  Trainable params: 80,299 (313.67 KB)
#  Non-trainable params: 176 (704.00 B)

# %%
model_filename = model_folder+'/CNN_Multiclass_F_Fi_NM_{epoch}.keras'

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath = model_filename,
    monitor='val_loss',
    verbose=0,    
    save_best_only=False,
    save_weights_only=False,
    mode='min',
    save_freq='epoch',
    initial_value_threshold=None
)

# %%
model.compile(optimizer = "Adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
#Training Data****************************************
ori_fe_fi_training_data_path='Data_Preprocessing/data_split_original/training_data/Fe_Fi_NM'
ori_fe_fi_validation_data_path='Data_Preprocessing/data_split_original/validation_data/Fe_Fi_NM'
ori_fe_fi_testing_data_path='Data_Preprocessing/data_split_original/testing_data/Fe_Fi_NM'
save_train_dir='Data_Preprocessing/on_the_fly/Fe_Fi_NM/train'
save_val_dir='Data_Preprocessing/on_the_fly/Fe_Fi_NM/valid'
save_test_dir='Data_Preprocessing/on_the_fly/Fe_Fi_NM/test'
#*****************************************************

delete_files_in_directory(save_train_dir)
delete_files_in_directory(save_val_dir)
delete_files_in_directory(save_test_dir)

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    ori_fe_fi_training_data_path,
    target_size=(imsize, imsize),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    shuffle=True,
    # save_to_dir=save_train_dir
)

val_generator = val_datagen.flow_from_directory(
    ori_fe_fi_validation_data_path,
    target_size=(imsize, imsize),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    shuffle=False,
    # save_to_dir=save_val_dir
)

test_generator = test_datagen.flow_from_directory(
    ori_fe_fi_testing_data_path,
    target_size=(imsize, imsize),
    batch_size=batch_size,
    # save_to_dir=save_test_dir,
    class_mode='categorical',
    color_mode='grayscale',
    shuffle=False
)
# Out:
# All files in Data_Preprocessing/on_the_fly/Fe_Fi_NM/train deleted successfully.
# All files in Data_Preprocessing/on_the_fly/Fe_Fi_NM/valid deleted successfully.
# All files in Data_Preprocessing/on_the_fly/Fe_Fi_NM/test deleted successfully.
# Found 152 images belonging to 3 classes.
# Found 71 images belonging to 3 classes.
# Found 71 images belonging to 3 classes.

# %%
history = model.fit(train_generator, 
                    epochs=num_epochs, 
                    validation_data=val_generator, 
                    batch_size=batch_size, 
                    callbacks=[model_checkpoint])
# Out:
# d:\projects\cnn-mp-dos\venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - accuracy: 0.4903 - loss: 1.0656 - val_accuracy: 0.3380 - val_loss: 1.1099
# Epoch 2/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 0.7491 - loss: 0.6087 - val_accuracy: 0.3380 - val_loss: 1.1242
# Epoch 3/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.7483 - loss: 0.5573 - val_accuracy: 0.3380 - val_loss: 1.1887
# Epoch 4/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.8204 - loss: 0.4195 - val_accuracy: 0.3380 - val_loss: 1.2743
# Epoch 5/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.7771 - loss: 0.4506 - val_accuracy: 0.3380 - val_loss: 1.3629
# Epoch 6/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.8240 - loss: 0.3990 - val_accuracy: 0.3380 - val_loss: 1.4394
# Epoch 7/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.8626 - loss: 0.2961 - val_accuracy: 0.3380 - val_loss: 1.5138
# Epoch 8/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.8662 - loss: 0.3551 - val_accuracy: 0.3380 - val_loss: 1.5705
# Epoch 9/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.9034 - loss: 0.2256 - val_accuracy: 0.3380 - val_loss: 1.6179
# Epoch 10/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 0.9643 - loss: 0.1620 - val_accuracy: 0.3380 - val_loss: 1.6705
# Epoch 11/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 226ms/step - accuracy: 0.9728 - loss: 0.1866 - val_accuracy: 0.3380 - val_loss: 1.7141
# Epoch 12/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.9838 - loss: 0.1275 - val_accuracy: 0.3380 - val_loss: 1.7649
# Epoch 13/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 299ms/step - accuracy: 0.9711 - loss: 0.1278 - val_accuracy: 0.3380 - val_loss: 1.8109
# Epoch 14/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 221ms/step - accuracy: 0.9791 - loss: 0.1201 - val_accuracy: 0.3380 - val_loss: 1.8524
# Epoch 15/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - accuracy: 0.9988 - loss: 0.0795 - val_accuracy: 0.3380 - val_loss: 1.8629
# Epoch 16/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.9848 - loss: 0.0835 - val_accuracy: 0.3380 - val_loss: 1.8449
# Epoch 17/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9480 - loss: 0.1085 - val_accuracy: 0.3380 - val_loss: 1.8196
# Epoch 18/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9542 - loss: 0.1090 - val_accuracy: 0.3380 - val_loss: 1.8316
# Epoch 19/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.9841 - loss: 0.1001 - val_accuracy: 0.3380 - val_loss: 1.6956
# Epoch 20/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9974 - loss: 0.0603 - val_accuracy: 0.3380 - val_loss: 1.6166
# Epoch 21/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.9966 - loss: 0.0408 - val_accuracy: 0.3380 - val_loss: 1.4541
# Epoch 22/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 1.0000 - loss: 0.0321 - val_accuracy: 0.3380 - val_loss: 1.3628
# Epoch 23/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - accuracy: 0.9884 - loss: 0.0589 - val_accuracy: 0.3380 - val_loss: 1.4004
# Epoch 24/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.9974 - loss: 0.0446 - val_accuracy: 0.3380 - val_loss: 1.4252
# Epoch 25/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 1.0000 - loss: 0.0439 - val_accuracy: 0.3380 - val_loss: 1.3606
# Epoch 26/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - accuracy: 0.9955 - loss: 0.0486 - val_accuracy: 0.3380 - val_loss: 1.3259
# Epoch 27/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - accuracy: 0.9910 - loss: 0.0370 - val_accuracy: 0.3380 - val_loss: 1.2540
# Epoch 28/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 1.0000 - loss: 0.0209 - val_accuracy: 0.3380 - val_loss: 1.2249
# Epoch 29/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.9929 - loss: 0.0381 - val_accuracy: 0.3380 - val_loss: 1.1320
# Epoch 30/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.3380 - val_loss: 1.0949
# Epoch 31/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.3380 - val_loss: 1.0594
# Epoch 32/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.0177 - val_accuracy: 0.3380 - val_loss: 1.0587
# Epoch 33/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.3380 - val_loss: 1.0641
# Epoch 34/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 1.0000 - loss: 0.0222 - val_accuracy: 0.3380 - val_loss: 1.0673
# Epoch 35/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.3521 - val_loss: 1.0559
# Epoch 36/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.3803 - val_loss: 1.0171
# Epoch 37/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.9853 - loss: 0.0480 - val_accuracy: 0.3380 - val_loss: 1.2602
# Epoch 38/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 0.9912 - loss: 0.0348 - val_accuracy: 0.3380 - val_loss: 1.2554
# Epoch 39/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.3803 - val_loss: 1.0613
# Epoch 40/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.4085 - val_loss: 0.9954
# Epoch 41/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.4507 - val_loss: 0.9477
# Epoch 42/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 0.3944 - val_loss: 0.9979
# Epoch 43/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.9955 - loss: 0.0316 - val_accuracy: 0.3380 - val_loss: 1.3048
# Epoch 44/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.9822 - loss: 0.0565 - val_accuracy: 0.3662 - val_loss: 1.2288
# Epoch 45/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.9900 - loss: 0.0477 - val_accuracy: 0.3380 - val_loss: 1.3152
# Epoch 46/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 0.9820 - loss: 0.0693 - val_accuracy: 0.6620 - val_loss: 0.9123
# Epoch 47/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.9868 - loss: 0.0301 - val_accuracy: 0.6479 - val_loss: 0.8825
# Epoch 48/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.9778 - loss: 0.0593 - val_accuracy: 0.5634 - val_loss: 1.2947
# Epoch 49/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.9855 - loss: 0.0353 - val_accuracy: 0.5493 - val_loss: 1.2672
# Epoch 50/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.9969 - loss: 0.0255 - val_accuracy: 0.6056 - val_loss: 1.0560
# Epoch 51/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 1.0000 - loss: 0.0161 - val_accuracy: 0.6056 - val_loss: 0.9653
# Epoch 52/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 1.0000 - loss: 0.0262 - val_accuracy: 0.6479 - val_loss: 0.8131
# Epoch 53/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.7042 - val_loss: 0.6780
# Epoch 54/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.8451 - val_loss: 0.5409
# Epoch 55/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - accuracy: 0.9981 - loss: 0.0310 - val_accuracy: 0.8451 - val_loss: 0.4984
# Epoch 56/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 1.0000 - loss: 0.0171 - val_accuracy: 0.8310 - val_loss: 0.5645
# Epoch 57/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.7324 - val_loss: 0.7164
# Epoch 58/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.4789 - val_loss: 1.4744
# Epoch 59/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 0.4648 - val_loss: 1.4681
# Epoch 60/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.5211 - val_loss: 1.1700
# Epoch 61/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.6338 - val_loss: 0.8799
# Epoch 62/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.7606 - val_loss: 0.7261
# Epoch 63/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 1.0000 - loss: 0.0713 - val_accuracy: 0.8028 - val_loss: 0.5522
# Epoch 64/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.8028 - val_loss: 0.5292
# Epoch 65/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.9876 - loss: 0.0313 - val_accuracy: 0.8169 - val_loss: 0.5274
# Epoch 66/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.8169 - val_loss: 0.5737
# Epoch 67/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.9800 - loss: 0.0530 - val_accuracy: 0.8028 - val_loss: 0.6570
# Epoch 68/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.6620 - val_loss: 1.0733
# Epoch 69/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - accuracy: 0.9711 - loss: 0.0827 - val_accuracy: 0.7324 - val_loss: 0.9095
# Epoch 70/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 0.9912 - loss: 0.0310 - val_accuracy: 0.8028 - val_loss: 0.4886
# Epoch 71/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.9727 - loss: 0.0439 - val_accuracy: 0.4366 - val_loss: 2.1803
# Epoch 72/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.9720 - loss: 0.0677 - val_accuracy: 0.4507 - val_loss: 2.3845
# Epoch 73/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step - accuracy: 0.9771 - loss: 0.1139 - val_accuracy: 0.5211 - val_loss: 1.5375
# Epoch 74/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.9956 - loss: 0.0320 - val_accuracy: 0.6338 - val_loss: 1.1674
# Epoch 75/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 0.7465 - val_loss: 0.8870
# Epoch 76/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.9948 - loss: 0.0271 - val_accuracy: 0.7324 - val_loss: 1.0004
# Epoch 77/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step - accuracy: 0.9654 - loss: 0.0681 - val_accuracy: 0.7887 - val_loss: 0.6338
# Epoch 78/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.8592 - val_loss: 0.6142
# Epoch 79/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.8169 - val_loss: 0.6186
# Epoch 80/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.9768 - loss: 0.1325 - val_accuracy: 0.8028 - val_loss: 0.7292
# Epoch 81/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step - accuracy: 1.0000 - loss: 0.0251 - val_accuracy: 0.7887 - val_loss: 0.9239
# Epoch 82/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.7746 - val_loss: 0.9746
# Epoch 83/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.7746 - val_loss: 0.8233
# Epoch 84/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.7746 - val_loss: 0.7561
# Epoch 85/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.7746 - val_loss: 0.8106
# Epoch 86/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.7465 - val_loss: 0.8456
# Epoch 87/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.7606 - val_loss: 0.8299
# Epoch 88/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.7465 - val_loss: 0.8213
# Epoch 89/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.7465 - val_loss: 0.8782
# Epoch 90/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.7465 - val_loss: 0.8806
# Epoch 91/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.7465 - val_loss: 0.8837
# Epoch 92/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 1.0000 - loss: 0.0141 - val_accuracy: 0.7465 - val_loss: 0.8864
# Epoch 93/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.7746 - val_loss: 0.8750
# Epoch 94/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.7746 - val_loss: 0.8731
# Epoch 95/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.7606 - val_loss: 0.8950
# Epoch 96/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.7606 - val_loss: 0.8934
# Epoch 97/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.7746 - val_loss: 0.8702
# Epoch 98/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.7887 - val_loss: 0.8453
# Epoch 99/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.7887 - val_loss: 0.8438
# Epoch 100/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.7887 - val_loss: 0.8386
# Epoch 101/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.7887 - val_loss: 0.8584
# Epoch 102/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.7887 - val_loss: 0.8480
# Epoch 103/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7887 - val_loss: 0.8456
# Epoch 104/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.7887 - val_loss: 0.8589
# Epoch 105/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.7887 - val_loss: 0.8794
# Epoch 106/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.9931 - loss: 0.0209 - val_accuracy: 0.7887 - val_loss: 0.9406
# Epoch 107/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9883 - loss: 0.0361 - val_accuracy: 0.7606 - val_loss: 1.0778
# Epoch 108/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.5915 - val_loss: 1.2447
# Epoch 109/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.9827 - loss: 0.0309 - val_accuracy: 0.8310 - val_loss: 0.7721
# Epoch 110/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.9854 - loss: 0.0333 - val_accuracy: 0.8028 - val_loss: 0.7885
# Epoch 111/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.7746 - val_loss: 1.1406
# Epoch 112/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.7746 - val_loss: 0.8559
# Epoch 113/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.8028 - val_loss: 0.9089
# Epoch 114/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 1.0000 - loss: 0.0323 - val_accuracy: 0.7887 - val_loss: 0.8706
# Epoch 115/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.7042 - val_loss: 1.1704
# Epoch 116/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.6620 - val_loss: 1.2918
# Epoch 117/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.5634 - val_loss: 1.4573
# Epoch 118/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.7887 - val_loss: 0.6830
# Epoch 119/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.7887 - val_loss: 0.7980
# Epoch 120/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.9988 - loss: 0.0069 - val_accuracy: 0.7887 - val_loss: 0.8435
# Epoch 121/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.9965 - loss: 0.0186 - val_accuracy: 0.8028 - val_loss: 0.6661
# Epoch 122/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.8310 - val_loss: 0.6873
# Epoch 123/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8592 - val_loss: 0.7234
# Epoch 124/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.7887 - val_loss: 0.7795
# Epoch 125/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.7887 - val_loss: 0.8022
# Epoch 126/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.7887 - val_loss: 0.8150
# Epoch 127/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.7746 - val_loss: 0.8230
# Epoch 128/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.7746 - val_loss: 0.8358
# Epoch 129/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.7887 - val_loss: 0.8578
# Epoch 130/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.9965 - loss: 0.0062 - val_accuracy: 0.7746 - val_loss: 1.2022
# Epoch 131/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.9735 - loss: 0.0693 - val_accuracy: 0.7324 - val_loss: 0.8644
# Epoch 132/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - accuracy: 0.9897 - loss: 0.0405 - val_accuracy: 0.5070 - val_loss: 3.0609
# Epoch 133/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.9865 - loss: 0.0424 - val_accuracy: 0.3521 - val_loss: 4.8312
# Epoch 134/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step - accuracy: 0.9829 - loss: 0.0306 - val_accuracy: 0.3803 - val_loss: 4.7358
# Epoch 135/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.3944 - val_loss: 4.4105
# Epoch 136/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 0.4225 - val_loss: 4.1977
# Epoch 137/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9752 - loss: 0.0316 - val_accuracy: 0.4085 - val_loss: 4.0292
# Epoch 138/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.9748 - loss: 0.0474 - val_accuracy: 0.4225 - val_loss: 3.4077
# Epoch 139/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - accuracy: 0.9981 - loss: 0.0069 - val_accuracy: 0.4930 - val_loss: 2.5462
# Epoch 140/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.9694 - loss: 0.0453 - val_accuracy: 0.4930 - val_loss: 2.3710
# Epoch 141/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - accuracy: 0.9903 - loss: 0.0355 - val_accuracy: 0.4507 - val_loss: 2.7401
# Epoch 142/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.9814 - loss: 0.0270 - val_accuracy: 0.6761 - val_loss: 1.8127
# Epoch 143/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.8169 - val_loss: 0.8699
# Epoch 144/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.9835 - loss: 0.0346 - val_accuracy: 0.8028 - val_loss: 0.8583
# Epoch 145/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step - accuracy: 0.9962 - loss: 0.0191 - val_accuracy: 0.5775 - val_loss: 2.4968
# Epoch 146/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - accuracy: 0.9965 - loss: 0.0213 - val_accuracy: 0.4507 - val_loss: 5.1565
# Epoch 147/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.4930 - val_loss: 3.7216
# Epoch 148/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.9929 - loss: 0.0441 - val_accuracy: 0.5634 - val_loss: 2.1144
# Epoch 149/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.9926 - loss: 0.0906 - val_accuracy: 0.4789 - val_loss: 3.5934
# Epoch 150/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 0.4085 - val_loss: 5.3289

# %%
plt.subplots(figsize=(4,3));
plt.plot(history.history['accuracy']);
plt.plot(history.history['val_accuracy']);
plt.ylabel('Accuracy', color='red', fontsize = 15);
plt.xlabel('Epoch', color='red', fontsize = 15);
plt.legend(['Training Accuracy', 'Validation Accuracy']);
plt.grid()

# %%
plt.subplots(figsize=(7, 5));
plt.plot(history.history['loss']);
plt.plot(history.history['val_loss']);
plt.ylabel('Loss', color='red', fontsize = 15);
plt.xlabel('Epoch', color='red', fontsize = 15);
plt.legend(['Training Loss', 'Validation Loss']);
plt.grid()

# %% [markdown]
# **EVALUATING ALL MODELS**: *Selecting BEST MODEL (BEST ACCURACY)*

# %%
test_generator.class_indices
# Out:
# {'class_fe': 0, 'class_fi': 1, 'class_nm': 2}

# %%
import re
model_folder='Model/Fe_Fi_NM'
LABELS=['Ferromagnetic','Ferrimagnetic', 'Non_Magnetic']
dir_list = os.listdir(model_folder)
best_epoch=-1
best_model=''
acc_max=-1
actual_class = test_generator.labels #np.argmax(testY,axis=1)
for filename in dir_list:
    model_check = tf.keras.models.load_model(model_folder+'/'+filename)
    predicted_class =np.argmax(((model_check.predict(test_generator,verbose=0) > .5).astype(int)),axis=1)
    report=classification_report(actual_class, predicted_class, target_names=LABELS,output_dict=True,zero_division=np.nan)
    if report['accuracy']>acc_max:
        best_model=model_folder+'/'+filename
        r=re.findall('[0-9]+', filename)
        best_epoch=int(r[0])
        acc_max=report['accuracy']

model_best = tf.keras.models.load_model(best_model)
predicted_class =np.argmax(((model_best.predict(test_generator) > .5).astype(int)),axis=1)
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000022138F03DC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000022138F03DC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step

# %%
report=classification_report(actual_class, predicted_class, target_names=LABELS)
print('Best model: ', best_model)
print('=======================================================')
print(report)
# Out:
# Best model:  Model/Fe_Fi_NM/CNN_Multiclass_F_Fi_NM_109.keras
# =======================================================
#                precision    recall  f1-score   support
#
# Ferromagnetic       0.62      0.83      0.71        24
# Ferrimagnetic       0.80      0.57      0.67        21
#  Non_Magnetic       0.96      0.88      0.92        26
#
#      accuracy                           0.77        71
#     macro avg       0.79      0.76      0.77        71
#  weighted avg       0.80      0.77      0.78        71

# %%
cf_mtx = confusion_matrix(actual_class, predicted_class)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(3,3)

plt.figure(figsize = (5, 4))
sns.heatmap(cf_mtx, xticklabels=LABELS, yticklabels=LABELS,
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
import pandas as pd
train_loss,train_acc=model_best.evaluate(train_generator,verbose=0)
val_loss,val_acc=model_best.evaluate(val_generator,verbose=0)
test_loss,test_acc=model_best.evaluate(test_generator,verbose=0)
dict_df={'Accuracy':[train_acc,val_acc,test_acc],'Loss':[train_loss,val_loss,test_loss]}

print(f'Best Model: {best_model}')
df=pd.DataFrame(dict_df,index=['Training','Validation','Testing'])
df
# Out:
# Best Model: Model/Fe_Fi_NM/CNN_Multiclass_F_Fi_NM_109.keras
#             Accuracy      Loss
# Training    0.980263  0.035158
# Validation  0.830986  0.772126
# Testing     0.774648  1.278419
